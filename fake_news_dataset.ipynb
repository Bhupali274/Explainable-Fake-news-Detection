# %% [markdown]
# # Fake News Dataset
# Long fake news dataset embedded directly.

# %%
import pandas as pd

fake_news = ['Vaccines cause dangerous side effects according to viral posts', 'Aliens are secretly living among humans claims social media', 'Drinking salt water cures cancer says fake article', 'Miracle pill guarantees instant weight loss without exercise', 'Government hiding truth about 5G towers spreading radiation', 'Mobile phones proven to cause brain cancer claim', 'Cure for diabetes found overnight in secret lab', 'Earth is flat according to viral conspiracy video', 'Airplanes spray secret chemicals for population control', 'Stock market will crash tomorrow fake prediction', 'Fake news claims sunlight causes skin cancer instantly', 'Ancient prophecy predicts end of world next month', 'Drinking lemon water cures all diseases claim', 'Fake report says hospitals inject tracking chips', 'Viral post claims moon landing was staged', 'Herbal drink guarantees immunity against all viruses', 'Fake message says ATM notes will be banned', 'Government secretly controlling weather using machines', 'Fake claim that chocolate cures depression', 'Social media rumor says exams cancelled nationwide']

fake_df = pd.DataFrame({
    "text": fake_news,
    "label": 0
})

fake_df
