# %% [markdown]
# # True News Dataset
# Long true news dataset embedded directly.

# %%
import pandas as pd

true_news = ['Government announces new education policy', 'Scientists discover water on Mars', 'WHO releases new health advisory', 'ISRO successfully launches new satellite', 'Election commission announces polling dates', 'Supreme Court issues new legal guidelines', 'Researchers develop new cancer treatment', 'India signs international climate agreement', 'Central bank revises interest rates', 'New species discovered by scientists', 'Government launches digital health mission', 'Researchers publish study on climate change', 'NASA announces successful space mission', 'New highway project approved by government', 'WHO updates vaccination recommendations', 'Scientists confirm effectiveness of new vaccine', 'Education ministry releases exam guidelines', 'Meteorological department predicts rainfall', 'Parliament passes new economic bill', 'Medical researchers develop AI diagnostic tool']

true_df = pd.DataFrame({
    "text": true_news,
    "label": 1
})

true_df
